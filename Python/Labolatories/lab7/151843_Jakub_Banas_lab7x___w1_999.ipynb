# %% [markdown]
# ## Zadanie
# zmodyfikuj lub określ w poniższym kodzie zasięgi zmiennych tak aby otrzymać wydruk: `zasięgi są poprawne`
# !!! Nie zmieniaj żadnych wartości które są nadawane zmiennym.

# %%
nr_indeksu, imie, nazwisko = 151843, 'Jakub', 'Banaś'

var1 = nr_indeksu
var2 = 0

def fun1():
    var1 = 1
    var2 = 0

    def fun2():
        global var1, var2

        var1 = 0
        var2 = nr_indeksu
        return var1 + var2

    var3 = fun2() * var1 + var2
    return var1 + var2 + var3

var4 = fun1()

var5 = (var1 + var2 + var4)

if var2 < var1 <= var5 <= nr_indeksu:
    print('zasięgi są poprawne')
else:
    print('zmien zasiegi zmiennych')
print(var5)
print(nr_indeksu)
print("nie wiem co można zrobić więcej z tym zadaniem")
# Out:
# zmien zasiegi zmiennych
# 303687
# 151843
# nie wiem co można zrobić więcej z tym zadaniem

# %%
w1 = (f'{nr_indeksu}{var1}{var2}{var4}{var5}')
print(f'lab7x___w1_{w1}.ipynb')
# Out:
# lab7x___w1_151843151842.00151844303686.0.ipynb
